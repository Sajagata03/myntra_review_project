# %%
# basically we are extracting rvies from a particular and single product

import os

import time # to have the delay while scrapping

import requests  # requests to retrive the webpages

from bs4 import BeautifulSoup as bs #to pass the html content

from selenium import webdriver  # selenium :core element(v imp) that lets you automate the browser and interact with the dynamic content and 
# webriver : helps to automate the entire process (handles the webpages)

from selenium.webdriver.common.by import By # helps specifying how selenium should locate the web elements eg id column , tag name

# %%
from selenium import webdriver 

product = "anouk kurta" # defines the path to chrome webdriver executively


# initialize chrome webdriver
driver = webdriver.Chrome()

#navigate to the url
driver.get("https://www.myntra.com/kurta?rawQuery="+product)

# hence the page is loaded you can extract the page text

myntra_text = driver.page_source

myntra_html = bs(myntra_text,"html.parser")



# above we have initialized the web driver and asked it to open the chrome
# and then asked the drivr to got to that particular URL
# and thena sekd it to extract the entire page source

# %%
myntra_text
# Out:
# '<html lang="en"><head><title>Kurta | Buy Kurta Online in India at Best Price</title><meta name="theme-color" content="#fffff"><link rel="dns-prefetch preconnect" href="https://constant.myntassets.com"><link rel="dns-prefetch preconnect" href="https://assets.myntassets.com"><link rel="dns-prefetch preconnect" href="https//www.googletagmanager.com"><link rel="dns-prefetch preconnect" href="https//www.google-analytics.com"><link rel="dns-prefetch preconnect" href="https//connect.facebook.net"><link rel="dns-prefetch preconnect" href="https://www.facebook.com"><link rel="dns-prefetch preconnect" href="https://touch.myntra.com"><link rel="manifest" href="/manifest.json"><link rel="search" type="application/opensearchdescription+xml" href="https://www.myntra.com/opensearch.xml" title="Myntra Fashion Search"><link rel="apple-touch-icon" href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png">\n      <link rel="preload" as="script" href="https://constant.myntassets.
# ...

# %%
myntra_html
# Out:
# <html lang="en"><head><title>Kurta | Buy Kurta Online in India at Best Price</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/><link href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png" rel="apple-touch-icon"/>
# ...

# %%
# we have extracted the entire unordered list(ul) in the page
# we have extracted all the products from that page
pclass = myntra_html.find_all("ul", {'class':'results-base'})

# %%
# we selected the first ul in that particular page
pclass[0]
# Out:
# <ul class="results-base"><li class="product-base" id="38589707"><div class="product-thumbShim"></div><div class="product-ratingsContainer"><span>4</span><span class="myntraweb-sprite product-starIcon index-productRatingsExcellentIcon sprites-productRatingsExcellentIcon"></span><div class="product-ratingsCount"><div class="product-separator">|</div><!-- react-text: 330 -->12<!-- /react-text --></div></div><a data-refreshpage="true" href="kurtas/anouk+mirage/anouk-mirage-women-floral-printed-kurta/38589707/buy" style="display: block;" target="_blank"><div class="product-imageSliderContainer"><div class="product-sliderContainer" style="display: block;"><div style="background: rgb(255, 242, 223);"><div style="height: 280px; width: 100%;"><picture class="img-responsive" draggable="false" style="width: 100%; height: 100%; display: block;"><source srcset="https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/2025/DECEMBER/22/jjcMJNu0_f03034add5174ecc9e
# ...

# %%
for i in pclass:
    href = i.find_all('a', href=True)  # find all the anchor tags inside that product
    t=(href[0]['href'])

# anchor tags are nothing but the product's other photos
productlink = "https://www.myntra.com/"+t

productlink
# Out:
# 'https://www.myntra.com/kurtas/anouk+mirage/anouk-mirage-women-floral-printed-kurta/38589707/buy'

# %%
t
# Out:
# 'kurtas/anouk+mirage/anouk-mirage-women-floral-printed-kurta/38589707/buy'

# %%
driver.get(productlink)
proRes = driver.page_source

# %%
proRes_html = bs(proRes, "html.parser")
proRes_html
# Out:
# <html lang="en"><head><title>Buy Anouk Mirage Women Floral Printed Kurta  - Kurtas for Women 38589707 | Myntra</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/><link href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png" rel="apple-touch-icon"/>
# ...

# %%
# now we will try to get the product title from the html tag which is mentioned in the website

title_h= proRes_html.find_all('title')

# %%
title_h
# Out:
# [<title>Buy Anouk Mirage Women Floral Printed Kurta  - Kurtas for Women 38589707 | Myntra</title>]

# %%
title = title_h[0].text

# %%
title
# Out:
# 'Buy Anouk Mirage Women Floral Printed Kurta  - Kurtas for Women 38589707 | Myntra'

# %%
# we are extracting the rating of the product from the div class and inside that div we have class as index-overallrating

# try to check the class name like div or whatever by cntrl+shift+c or inspect by clicking right
overallRating = proRes_html.find_all("div",{"class":"index-overallRating"})
overallRating
# Out:
# [<div class="index-overallRating"><div>4</div><span class="myntraweb-sprite index-starIcon index-productRatingsExcellentIcon sprites-productRatingsExcellentIcon"></span><div class="index-separator">|</div><div class="index-ratingsCount"><!-- react-text: 78 -->12<!-- /react-text --><!-- react-text: 79 --> Ratings<!-- /react-text --></div></div>]

# %%
# we have so much info inside the div class so we are just extracting the text portion

for i in overallRating:
    rating_value = i.find('div').text
print(rating_value)
# Out:
# 4

# %%
# now we wre going to get the price

price = proRes_html.find_all("span", {"class":"pdp-price"})  # check this classes name by inspect method in the webpage

# %%
price
# Out:
# [<span class="pdp-price" tabindex="0"><strong>₹357</strong></span>]

# %%
for i in price:
    p = i.text
print(p)
# Out:
# ₹357

# %% [markdown]
# When we select a product and go to the review section we see only 2 or 3 reviews and a link is there as "read more reviews"
# So in below process we will try to et the info from that read more reviews webpage

# %%
Reviews = proRes_html.find("a",{"class":"detailed-reviews-allReviews"})
# 'a' is the anchor tag

# %%
Reviews

# %%
# in this code line we are getting the link for the webpage of reviews for the partiicular product
t2 = Reviews['href']
Review_Link = 'https://www.myntra.com'+t2
Review_Link
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[185], line 2
#       1 # in this code line we are getting the link for the webpage of reviews for the partiicular product
# ----> 2 t2 = Reviews['href']
#       3 Review_Link = 'https://www.myntra.com'+t2
#       4 Review_Link
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Now we will use our driver to get all the those reviews

driver.get(Review_Link)
review_page = driver.page_source

# %% [markdown]
# Whenever you run the driver code ensure you do it hand by hand with the website in the chrome

# %%
driver.quit()

# %%
# beautifying the page
review_html = bs(review_page, "html.parser")

# %%
review_html
# Out:
# <html lang="en"><head><title>Review - Anouk Women Floral Embroidered Flared Sleeves Thread Work Kurta</title><meta content="#fffff" name="theme-color"/><link href="https://constant.myntassets.com" rel="dns-prefetch preconnect"/><link href="https://assets.myntassets.com" rel="dns-prefetch preconnect"/><link href="https//www.googletagmanager.com" rel="dns-prefetch preconnect"/><link href="https//www.google-analytics.com" rel="dns-prefetch preconnect"/><link href="https//connect.facebook.net" rel="dns-prefetch preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch preconnect"/><link href="https://touch.myntra.com" rel="dns-prefetch preconnect"/><link href="/manifest.json" rel="manifest"/><link href="https://www.myntra.com/opensearch.xml" rel="search" title="Myntra Fashion Search" type="application/opensearchdescription+xml"/><link href="https://constant.myntassets.com/pwa/assets/img/Icon-App-60x60@3x_2021.png" rel="apple-touch-icon"/>
# ...

# %%
review = review_html.find_all("div", {"class":"detailed-reviews-userReviewsContainer"})

# %%
review
# Out:
# [<div class="detailed-reviews-userReviewsContainer" id="detailedReviewsContainer"><div class="user-review-userReviewWrapper"><div class="user-review-main user-review-showRating"><div class="user-review-starWrapper"><span class="user-review-starRating user-review-fiveStars"><!-- react-text: 180 -->5<!-- /react-text --><span class="user-review-starIcon"><svg height="10" viewbox="0 0 12 12" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M6 9.644l2.867 1.821c.464.296.743.093.623-.45L8.724 7.56l2.581-2.657c.384-.395.25-.716-.306-.716H7.686L6.374.93c-.206-.513-.542-.512-.748 0L4.314 4.187H1.001c-.553 0-.687.324-.306.716L3.276 7.56l-.766 3.455c-.12.544.165.742.623.45L6 9.645z" fill="#FFF" fill-rule="evenodd"></path></svg></span></span></div><div class="user-review-reviewTextWrapper">I bought this Anouk Floral Yoke Design Notch Neck Thread Work Straight Kurta for my wife, and she absolutely loved it! The design is elegant and feminine, with beautiful thread work and floral detailing 
# ...

# %%
# now we will loop over the review div 
# we used everything because it is in a container
# whatever we have written with find_all it should be matched with the website's names which can be taken by inspecting the website 
# for eg check "user-review-main user-review-showRating" with the website

for i in review:
    user_rating = i.find_all("div",{'class':"user-review-main user-review-showRating"})
    user_comment = i.find_all("div",{"class":"user-review-reviewTextWrapper"})
    user_name = i.find_all("div",{"class":"user-review-left"})

# %%
user_rating
user_comment
user_name
# Out:
# [<div class="user-review-left"><span>Aniket Kanojiya</span><span>21 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Pinku</span><span>25 Aug 2025</span></div>,
#  <div class="user-review-left"><span>Amrita Sahu</span><span>5 Nov 2025</span></div>,
#  <div class="user-review-left"><span>Adweeti Rout</span><span>1 Jan 2026</span></div>,
#  <div class="user-review-left"><span>Seema Gupta</span><span>9 Sept 2025</span></div>,
#  <div class="user-review-left"><span>Myntra Customer</span><span>18 Jan 2026</span></div>,
#  <div class="user-review-left"><span>Koyel Mahakul</span><span>5 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Anisha</span><span>12 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Priyanka Lande</span><span>15 Aug 2025</span></div>,
#  <div class="user-review-left"><span>Shwet Prabha Baiswar</span><span>16 Nov 2025</span></div>,
#  <div class="user-review-left"><span>Surbhi</span><span>15 Jan 2026</span></div>,
# ...

# %%
user_comment
# Out:
# [<div class="user-review-reviewTextWrapper">I bought this Anouk Floral Yoke Design Notch Neck Thread Work Straight Kurta for my wife, and she absolutely loved it! The design is elegant and feminine, with beautiful thread work and floral detailing that looks even better in person. The fabric feels soft and comfortable, perfect for both everyday wear and small festive occasions.
#
#  The fit is true to size and gives a very graceful look. The color combination is subtle yet classy, and the overall finish reflects great craftsmanship. My wife received several compliments the first time she wore it — definitely a great buy from Anouk!
#
#  Highly recommended for anyone looking for something stylish, traditional, and comfortable.
#  </div>,
# ...

# %%
user_name
# Out:
# [<div class="user-review-left"><span>Aniket Kanojiya</span><span>21 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Pinku</span><span>25 Aug 2025</span></div>,
#  <div class="user-review-left"><span>Amrita Sahu</span><span>5 Nov 2025</span></div>,
#  <div class="user-review-left"><span>Adweeti Rout</span><span>1 Jan 2026</span></div>,
#  <div class="user-review-left"><span>Seema Gupta</span><span>9 Sept 2025</span></div>,
#  <div class="user-review-left"><span>Myntra Customer</span><span>18 Jan 2026</span></div>,
#  <div class="user-review-left"><span>Koyel Mahakul</span><span>5 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Anisha</span><span>12 Oct 2025</span></div>,
#  <div class="user-review-left"><span>Priyanka Lande</span><span>15 Aug 2025</span></div>,
#  <div class="user-review-left"><span>Shwet Prabha Baiswar</span><span>16 Nov 2025</span></div>,
#  <div class="user-review-left"><span>Surbhi</span><span>15 Jan 2026</span></div>,
# ...

# %%
user_rating
# Out:
# [<div class="user-review-main user-review-showRating"><div class="user-review-starWrapper"><span class="user-review-starRating user-review-fiveStars"><!-- react-text: 180 -->5<!-- /react-text --><span class="user-review-starIcon"><svg height="10" viewbox="0 0 12 12" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M6 9.644l2.867 1.821c.464.296.743.093.623-.45L8.724 7.56l2.581-2.657c.384-.395.25-.716-.306-.716H7.686L6.374.93c-.206-.513-.542-.512-.748 0L4.314 4.187H1.001c-.553 0-.687.324-.306.716L3.276 7.56l-.766 3.455c-.12.544.165.742.623.45L6 9.645z" fill="#FFF" fill-rule="evenodd"></path></svg></span></span></div><div class="user-review-reviewTextWrapper">I bought this Anouk Floral Yoke Design Notch Neck Thread Work Straight Kurta for my wife, and she absolutely loved it! The design is elegant and feminine, with beautiful thread work and floral detailing that looks even better in person. The fabric feels soft and comfortable, perfect for both everyday wear and small festive oc
# ...

# %%
# to view everything in text only
for i in range(len(user_rating)):
    rating= user_rating[i].find('span',class_='user-review-starRating').get_text().strip()
    comment = user_comment[i].text
    name = user_name[i].find('span').text
    date = user_name[i].find_all('span')[1].text
    print(f"Date:{date},Rating:{rating}, Name:{name}, comment:{comment}")
# Out:
# Date:21 Oct 2025,Rating:5, Name:Aniket Kanojiya, comment:I bought this Anouk Floral Yoke Design Notch Neck Thread Work Straight Kurta for my wife, and she absolutely loved it! The design is elegant and feminine, with beautiful thread work and floral detailing that looks even better in person. The fabric feels soft and comfortable, perfect for both everyday wear and small festive occasions.
#
# The fit is true to size and gives a very graceful look. The color combination is subtle yet classy, and the overall finish reflects great craftsmanship. My wife received several compliments the first time she wore it — definitely a great buy from Anouk!
#
# Highly recommended for anyone looking for something stylish, traditional, and comfortable.
#
# ...

# %%
for i in user_comment:
    com = i.text
    print(com)
# Out:
# I bought this Anouk Floral Yoke Design Notch Neck Thread Work Straight Kurta for my wife, and she absolutely loved it! The design is elegant and feminine, with beautiful thread work and floral detailing that looks even better in person. The fabric feels soft and comfortable, perfect for both everyday wear and small festive occasions.
#
# The fit is true to size and gives a very graceful look. The color combination is subtle yet classy, and the overall finish reflects great craftsmanship. My wife received several compliments the first time she wore it — definitely a great buy from Anouk!
#
# Highly recommended for anyone looking for something stylish, traditional, and comfortable.
#
# Amazing product 😍I really loved this kurta. This material is super soft and very comfortable. The fitting is perfect and stitching is neat.The colour and design Are also beautiful exactly as shown in picture. Received good quality 👍thank you Myntra 🥳Go for it👍
# ...
